# %%
import os
import sys

os.environ["MUJOCO_GL"] = "egl"
# 在Jupyter Notebook中，使用当前工作目录代替__file__
curdir = os.getcwd()
sys.path.append(os.path.dirname(curdir))

from tqdm import tqdm
import time
import mediapy as media
import envs.dmcenv as dmcenv
import numpy as np

def random_action(action_size):
    return np.random.uniform(-1, 1, (action_size))
# Out:
# DMCAnt-v0 registered
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import gymnasium as gym

env = gym.make(
    "Ant-v5",
    render_mode="rgb_array",
    camera_name="egocentric",
    width=64,
    height=64,
    xml_file="/mnt/disk2/xh2/ai4neuron/derl/custom_envs/asset/ant_mjx.xml",
)
obs, info = env.reset()
try:
    print(f"{obs.shape = }")
except AttributeError:
    print(f"{obs = }")
print(f"{env.action_space.shape = }")

action_size = env.action_space.shape[0]



obs, reward, terminated, truncated, info = env.step(random_action(action_size))
print(f"{reward = }")
print(f"{terminated = }")
print(f"{truncated = }")
print(f"{info = }")


repeat_times = 2_000
st = time.time()
video1 = []
for i in tqdm(range(repeat_times)):
    o, r, d, t, info = env.step(random_action(action_size))
    rgb_image = env.render()
    video1.append(rgb_image)
    
et = time.time()

print(f"fps: {repeat_times / (et - st)}")
# show video
media.show_video(video1, fps=30)

# %%
def visualize_env(env):
    env.debug(True)
    obs, info = env.reset()
    # print(f"{obs = }")
    print(f"{env.action_space.shape = }")
    action_size = env.action_space.shape[0]
    obs, reward, terminated, truncated, info = env.step(random_action(action_size))
    print(f"{reward = }")
    print(f"{terminated = }")
    print(f"{truncated = }")
    print(f"{info = }")
    repeat_times = 300
    st = time.time()
    video1 = []
    video2 = []
    for i in tqdm(range(repeat_times)):
        obs, reward, terminated, truncated, info = env.step(random_action(action_size))
        if i % 100 == 0:
            obs, info = env.reset()
        video1.append(obs["image"])
        video2.append(env._env.physics.render(camera_id=0, width=128, height=128))
    et = time.time()

    print(f"fps: {repeat_times / (et - st)}")

    media.show_video(video1, fps=30)
    media.show_video(video2, fps=30)

# visualize_env(dmcenv.DMCEnv(walker_name="Ant", task_name="Gaps"))

# visualize_env(dmcenv.DMCEnv(walker_name="Ant", task_name="Floor"))

# visualize_env(dmcenv.DMCEnv(walker_name="Humanoid", task_name="Escape"))

# visualize_env(dmcenv.DMCEnv(walker_name="Humanoid", task_name="Gaps"))

visualize_env(dmcenv.DMCEnv(walker_name="Ant", task_name="Maze"))
# Out:
# walker_name ='Ant', task_name = 'Maze'
# *************
# *   *       *
# *   *   *****
# *         P *
# **  **  **  *
# *           *
# *   *****   *
# *   *****   *
# *   *****   *
# *G  *****   *
# *************
#
# env.action_space.shape = (8,)
# reward = 0
# terminated = False
# truncated = False
# info = {'timestep.discount': 1.0, 'timestep.step_type': <StepType.MID: 1>}
# 100%|██████████| 300/300 [00:54<00:00,  5.49it/s]
# fps: 5.488689208099835
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="64" height="64" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="128" height="128" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
